# %%
import os # directory management
import pandas as pd # data analysis
from scipy import stats # descriptive statistics
import matplotlib.pyplot as plt # figures
import numpy as np # maths
import seaborn as sns

# %% [markdown]
# # Dataset I: New Orleans Housing Prices

# %%
df = pd.read_csv('new_orleans_airbnb_listings.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           6028 non-null   int64
#  1   name                         6028 non-null   object
#  2   description                  6000 non-null   object
#  3   neighborhood_overview        4614 non-null   object
#  4   host_id                      6028 non-null   int64
#  5   host_since                   5990 non-null   object
#  6   host_location                5983 non-null   object
#  7   host_response_time           4449 non-null   object
#  8   host_response_rate           4449 non-null   object
#  9   host_acceptance_rate         4562 non-null   object
#  10  host_is_superhost            5990 non-null   object
#  11  host_listings_count          5990 non-null   float64
#  12  host_verifications           6028 non-null   object
#  13  host_has_profile_pic         5990 non-null   object
#  14  host_neighbourhood           5358 non-null   object
#  15  host_identity_verified       5990 non-null   object
#  16  neighbourhood_cleansed       6028 non-null   object
#  17  latitude                     6028 non-null   float64
#  18  longitude                    6028 non-null   float64
#  19  property_type                6028 non-null   object
#  20  room_type                    6028 non-null   object
#  21  accommodates                 6028 non-null   int64
#  22  bathrooms_text               6012 non-null   object
#  23  bedrooms                     5725 non-null   float64
#  24  beds                         5906 non-null   float64
#  25  amenities                    6028 non-null   object
#  26  price                        6028 non-null   object
#  27  minimum_nights               6028 non-null   int64
#  28  maximum_nights               6028 non-null   int64
#  29  has_availability             6028 non-null   object
#  30  availability_30              6028 non-null   int64
#  31  availability_60              6028 non-null   int64
#  32  availability_90              6028 non-null   int64
#  33  availability_365             6028 non-null   int64
#  34  number_of_reviews            6028 non-null   int64
#  35  number_of_reviews_ltm        6028 non-null   int64
#  36  number_of_reviews_l30d       6028 non-null   int64
#  37  first_review                 5356 non-null   object
#  38  last_review                  5356 non-null   object
#  39  review_scores_rating         5356 non-null   float64
#  40  review_scores_accuracy       5341 non-null   float64
#  41  review_scores_cleanliness    5343 non-null   float64
#  42  review_scores_checkin        5341 non-null   float64
#  43  review_scores_communication  5342 non-null   float64
#  44  review_scores_location       5341 non-null   float64
#  45  review_scores_value          5341 non-null   float64
#  46  license                      5543 non-null   object
#  47  instant_bookable             6028 non-null   object
#  48  reviews_per_month            5356 non-null   float64
# dtypes: float64(13), int64(12), object(24)
# memory usage: 2.3+ MB

# %%
df['price'] = df['price'].str.replace('$', '')  # remove $ sign
df['price'] = df['price'].str.replace(',', '')  # remove , sign
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16852\3275613283.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['price'] = df['price'].str.replace('$', '')  # remove $ sign

# %%
# convert data type to float of price
df['price'] = df['price'].astype(float)
df['price'].describe()
# Out:
# count    6028.000000
# mean      225.361314
# std       235.789359
# min         0.000000
# 25%       105.000000
# 50%       158.000000
# 75%       258.000000
# max      4657.000000
# Name: price, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6028 entries, 0 to 6027
# Data columns (total 49 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           6028 non-null   int64
#  1   name                         6028 non-null   object
#  2   description                  6000 non-null   object
#  3   neighborhood_overview        4614 non-null   object
#  4   host_id                      6028 non-null   int64
#  5   host_since                   5990 non-null   object
#  6   host_location                5983 non-null   object
#  7   host_response_time           4449 non-null   object
#  8   host_response_rate           4449 non-null   object
#  9   host_acceptance_rate         4562 non-null   object
#  10  host_is_superhost            5990 non-null   object
#  11  host_listings_count          5990 non-null   float64
#  12  host_verifications           6028 non-null   object
#  13  host_has_profile_pic         5990 non-null   object
#  14  host_neighbourhood           5358 non-null   object
#  15  host_identity_verified       5990 non-null   object
#  16  neighbourhood_cleansed       6028 non-null   object
#  17  latitude                     6028 non-null   float64
#  18  longitude                    6028 non-null   float64
#  19  property_type                6028 non-null   object
#  20  room_type                    6028 non-null   object
#  21  accommodates                 6028 non-null   int64
#  22  bathrooms_text               6012 non-null   object
#  23  bedrooms                     5725 non-null   float64
#  24  beds                         5906 non-null   float64
#  25  amenities                    6028 non-null   object
#  26  price                        6028 non-null   float64
#  27  minimum_nights               6028 non-null   int64
#  28  maximum_nights               6028 non-null   int64
#  29  has_availability             6028 non-null   object
#  30  availability_30              6028 non-null   int64
#  31  availability_60              6028 non-null   int64
#  32  availability_90              6028 non-null   int64
#  33  availability_365             6028 non-null   int64
#  34  number_of_reviews            6028 non-null   int64
#  35  number_of_reviews_ltm        6028 non-null   int64
#  36  number_of_reviews_l30d       6028 non-null   int64
#  37  first_review                 5356 non-null   object
#  38  last_review                  5356 non-null   object
#  39  review_scores_rating         5356 non-null   float64
#  40  review_scores_accuracy       5341 non-null   float64
#  41  review_scores_cleanliness    5343 non-null   float64
#  42  review_scores_checkin        5341 non-null   float64
#  43  review_scores_communication  5342 non-null   float64
#  44  review_scores_location       5341 non-null   float64
#  45  review_scores_value          5341 non-null   float64
#  46  license                      5543 non-null   object
#  47  instant_bookable             6028 non-null   object
#  48  reviews_per_month            5356 non-null   float64
# dtypes: float64(14), int64(12), object(23)
# memory usage: 2.3+ MB

# %%
# numeric data
df.describe()
# Out:
#                  id       host_id  host_listings_count     latitude  \
# count  6.028000e+03  6.028000e+03          5990.000000  6028.000000
# mean   3.096340e+07  1.261613e+08            46.634224    29.957344
# std    1.522782e+07  1.194316e+08           198.528224     0.022954
# min    1.909100e+04  5.146000e+03             0.000000    29.899070
# 25%    1.840335e+07  2.554932e+07             1.000000    29.940738
# 50%    3.228621e+07  9.466656e+07             2.000000    29.956640
# 75%    4.472240e+07  1.949531e+08            12.000000    29.969393
# max    5.315408e+07  4.282765e+08          3186.000000    30.160150
#
#          longitude  accommodates     bedrooms         beds        price  \
# count  6028.000000   6028.000000  5725.000000  5906.000000  6028.000000
# mean    -90.074508      4.890511     2.126288     2.825601   225.361314
# std       0.028415      2.914003     1.401288     2.181143   235.789359
# min     -90.137480      0.000000     1.000000     1.000000     0.000000
# 25%     -90.089010      2.000000     1.000000     1.000000   105.000000
# 50%     -90.073320      4.000000     2.000000     2.000000   158.000000
# 75%     -90.063517      6.000000     3.000000     4.000000   258.000000
# max     -89.738090     16.000000    23.000000    30.000000  4657.000000
#
#        minimum_nights  ...  number_of_reviews_ltm  number_of_reviews_l30d  \
# count     6028.000000  ...            6028.000000             6028.000000
# mean         8.938288  ...              13.503650                1.157764
# std         17.625508  ...              19.153095                1.750629
# min          1.000000  ...               0.000000                0.000000
# 25%          1.000000  ...               0.000000                0.000000
# 50%          2.000000  ...               6.000000                0.000000
# 75%          3.000000  ...              21.000000                2.000000
# max        365.000000  ...             359.000000               18.000000
#
#        review_scores_rating  review_scores_accuracy  \
# count           5356.000000             5341.000000
# mean               4.770147                4.831558
# std                0.395421                0.299826
# min                0.000000                1.000000
# 25%                4.710000                4.800000
# 50%                4.860000                4.910000
# 75%                4.960000                4.980000
# max                5.000000                5.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count                5343.000000            5341.000000
# mean                    4.790548               4.893647
# std                     0.324464               0.250731
# min                     1.000000               1.000000
# 25%                     4.730000               4.890000
# 50%                     4.880000               4.960000
# 75%                     4.980000               5.000000
# max                     5.000000               5.000000
#
#        review_scores_communication  review_scores_location  \
# count                  5342.000000             5341.000000
# mean                      4.869369                4.770092
# std                       0.268262                0.322707
# min                       1.000000                1.000000
# 25%                       4.850000                4.690000
# 50%                       4.950000                4.870000
# 75%                       5.000000                4.970000
# max                       5.000000                5.000000
#
#        review_scores_value  reviews_per_month
# count          5341.000000        5356.000000
# mean              4.753503           3.215560
# std               0.314243           7.813658
# min               1.000000           0.010000
# 25%               4.690000           0.750000
# 50%               4.830000           1.750000
# 75%               4.910000           3.322500
# max               5.000000         292.000000
#
# [8 rows x 26 columns]

# %%
# describe categorical variables
df.describe(include=['O'])
# Out:
#                                                      name  \
# count                                                6028
# unique                                               5752
# top     Sextant | The Lola | 5 min drive to Bourbon St...
# freq                                                   27
#
#                                               description  \
# count                                                6000
# unique                                               5486
# top     LOCATION: Being centrally located, you will ha...
# freq                                                   58
#
#             neighborhood_overview  host_since  \
# count                        4614        5990
# unique                       3455        1992
# top     Central Business District  2017-06-06
# freq                          239         244
#
#                                 host_location host_response_time  \
# count                                    5983               4449
# unique                                    269                  4
# top     New Orleans, Louisiana, United States     within an hour
# freq                                     4084               3658
#
#        host_response_rate host_acceptance_rate host_is_superhost  \
# count                4449                 4562              5990
# unique                 47                   77                 2
# top                  100%                 100%                 f
# freq                 3472                 1684              3306
#
#         host_verifications  ...     neighbourhood_cleansed  \
# count                 6028  ...                       6028
# unique                 233  ...                         67
# top     ['email', 'phone']  ...  Central Business District
# freq                   972  ...                        840
#
#                   property_type        room_type bathrooms_text  \
# count                      6028             6028           6012
# unique                       53                4             32
# top     Entire residential home  Entire home/apt         1 bath
# freq                       2101             5108           2775
#
#                                                 amenities has_availability  \
# count                                                6028             6028
# unique                                               5403                2
# top     ["Air conditioning", "Security cameras on prop...                t
# freq                                                   47             5983
#
#        first_review last_review  \
# count          5356        5356
# unique         1815         668
# top      2020-02-23  2021-11-01
# freq             31         439
#
#                                                   license instant_bookable
# count                                                5543             6028
# unique                                               3731                2
# top     Exempt: This listing is a licensed hotel, mote...                t
# freq                                                 1229             3228
#
# [4 rows x 23 columns]

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11912\3784545759.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr()
#
col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col9, #T_34cd4_row8_col10, #T_34cd4_row8_col17, #T_34cd4_row8_col20, #T_34cd4_row15_col9, #T_34cd4_row23_col14, #T_34cd4_row25_col8 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col12, #T_34cd4_row2_col5, #T_34cd4_row5_col13, #T_34cd4_row13_col17 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_34cd4_row1_col15, #T_34cd4_row1_col17, #T_34cd4_row3_col16, #T_34cd4_row6_col4, #T_34cd4_row10_col17, #T_34cd4_row17_col22, #T_34cd4_row20_col9 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col18, #T_34cd4_row4_col23, #T_34cd4_row13_col18, #T_34cd4_row13_col20, #T_34cd4_row13_col24, #T_34cd4_row19_col12, #T_34cd4_row22_col2, #T_34cd4_row22_col13 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col19, #T_34cd4_row1_col23, #T_34cd4_row14_col22, #T_34cd4_row19_col11, #T_34cd4_row22_col14, #T_34cd4_row23_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col20, #T_34cd4_row17_col7, #T_34cd4_row18_col11, #T_34cd4_row18_col12, #T_34cd4_row18_col13, #T_34cd4_row22_col11, #T_34cd4_row22_col12, #T_34cd4_row24_col14 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col21, #T_34cd4_row10_col20, #T_34cd4_row15_col13, #T_34cd4_row17_col2, #T_34cd4_row17_col6, #T_34cd4_row19_col14, #T_34cd4_row20_col2, #T_34cd4_row20_col11, #T_34cd4_row21_col13, #T_34cd4_row21_col14 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_34cd4_row1_col22, #T_34cd4_row11_col19, #T_34cd4_row13_col19, #T_34cd4_ro

# %% [markdown]
# # Dataset II: Property prices Ames, Iowa

# %%
df1 = pd.read_csv('C:/Users/User/OneDrive - Université Bretagne Sud/Machine Learning/Project/house-prices-advanced-regression-techniques/train.csv')
df2= pd.read_csv('C:/Users/User/OneDrive - Université Bretagne Sud/Machine Learning/Project/house-prices-advanced-regression-techniques/test.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
# handle missing values
# fill numeric nans with zero
for i in df1.columns:
    if df1[i].dtype == 'float64' or df1[i].dtype == 'int64':
        df1[i].fillna(0, inplace=True)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1460 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1460 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1455 non-null   object
#  3   LotFrontage    1232 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   object
#  6   Alley          107 non-null    object
#  7   LotShape       1459 non-null   object
#  8   LandContour    1459 non-null   object
#  9   Utilities      1457 non-null   object
#  10  LotConfig      1459 non-null   object
#  11  LandSlope      1459 non-null   object
#  12  Neighborhood   1459 non-null   object
#  13  Condition1     1459 non-null   object
#  14  Condition2     1459 non-null   object
#  15  BldgType       1459 non-null   object
#  16  HouseStyle     1459 non-null   object
#  17  OverallQual    1459 non-null   int64
#  18  OverallCond    1459 non-null   int64
#  19  YearBuilt      1459 non-null   int64
#  20  YearRemodAdd   1459 non-null   int64
#  21  RoofStyle      1459 non-null   object
#  22  RoofMatl       1459 non-null   object
#  23  Exterior1st    1458 non-null   object
#  24  Exterior2nd    1458 non-null   object
#  25  MasVnrType     1443 non-null   object
#  26  MasVnrArea     1444 non-null   float64
#  27  ExterQual      1459 non-null   object
#  28  ExterCond      1459 non-null   object
#  29  Foundation     1459 non-null   object
#  30  BsmtQual       1415 non-null   object
#  31  BsmtCond       1414 non-null   object
#  32  BsmtExposure   1415 non-null   object
#  33  BsmtFinType1   1417 non-null   object
#  34  BsmtFinSF1     1458 non-null   float64
#  35  BsmtFinType2   1417 non-null   object
#  36  BsmtFinSF2     1458 non-null   float64
#  37  BsmtUnfSF      1458 non-null   float64
#  38  TotalBsmtSF    1458 non-null   float64
#  39  Heating        1459 non-null   object
#  40  HeatingQC      1459 non-null   object
#  41  CentralAir     1459 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1459 non-null   int64
#  44  2ndFlrSF       1459 non-null   int64
#  45  LowQualFinSF   1459 non-null   int64
#  46  GrLivArea      1459 non-null   int64
#  47  BsmtFullBath   1457 non-null   float64
#  48  BsmtHalfBath   1457 non-null   float64
#  49  FullBath       1459 non-null   int64
#  50  HalfBath       1459 non-null   int64
#  51  BedroomAbvGr   1459 non-null   int64
#  52  KitchenAbvGr   1459 non-null   int64
#  53  KitchenQual    1458 non-null   object
#  54  TotRmsAbvGrd   1459 non-null   int64
#  55  Functional     1457 non-null   object
#  56  Fireplaces     1459 non-null   int64
#  57  FireplaceQu    729 non-null    object
#  58  GarageType     1383 non-null   object
#  59  GarageYrBlt    1381 non-null   float64
#  60  GarageFinish   1381 non-null   object
#  61  GarageCars     1458 non-null   float64
#  62  GarageArea     1458 non-null   float64
#  63  GarageQual     1381 non-null   object
#  64  GarageCond     1381 non-null   object
#  65  PavedDrive     1459 non-null   object
#  66  WoodDeckSF     1459 non-null   int64
#  67  OpenPorchSF    1459 non-null   int64
#  68  EnclosedPorch  1459 non-null   int64
#  69  3SsnPorch      1459 non-null   int64
#  70  ScreenPorch    1459 non-null   int64
#  71  PoolArea       1459 non-null   int64
#  72  PoolQC         3 non-null      object
#  73  Fence          290 non-null    object
#  74  MiscFeature    51 non-null     object
#  75  MiscVal        1459 non-null   int64
#  76  MoSold         1459 non-null   int64
#  77  YrSold         1459 non-null   int64
#  78  SaleType       1458 non-null   object
#  79  SaleCondition  1459 non-null   object
# dtypes: float64(11), int64(26), object(43)
# memory usage: 912.0+ KB

# %% [markdown]
# Note that test set doesn't have data for the dependent variable - Sale Price. Hence, only train set can be used for the analysis.

# %%
# correlation matrix with p values
corr_matrix = df1.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_11404\1522661039.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df1.corr()
# <style type="text/css">
# #T_c6d7c_row0_col0, #T_c6d7c_row1_col1, #T_c6d7c_row2_col2, #T_c6d7c_row3_col3, #T_c6d7c_row4_col4, #T_c6d7c_row5_col5, #T_c6d7c_row6_col6, #T_c6d7c_row7_col7, #T_c6d7c_row8_col8, #T_c6d7c_row9_col9, #T_c6d7c_row10_col10, #T_c6d7c_row11_col11, #T_c6d7c_row12_col12, #T_c6d7c_row13_col13, #T_c6d7c_row14_col14, #T_c6d7c_row15_col15, #T_c6d7c_row16_col16, #T_c6d7c_row17_col17, #T_c6d7c_row18_col18, #T_c6d7c_row19_col19, #T_c6d7c_row20_col20, #T_c6d7c_row21_col21, #T_c6d7c_row22_col22, #T_c6d7c_row23_col23, #T_c6d7c_row24_col24, #T_c6d7c_row25_col25, #T_c6d7c_row26_col26, #T_c6d7c_row27_col27, #T_c6d7c_row28_col28, #T_c6d7c_row29_col29, #T_c6d7c_row30_col30, #T_c6d7c_row31_col31, #T_c6d7c_row32_col32, #T_c6d7c_row33_col33, #T_c6d7c_row34_col34, #T_c6d7c_row35_col35, #T_c6d7c_row36_col36, #T_c6d7c_row37_col37 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6d7c_row0_
{
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_c6d7c_row0_col18, #T_c6d7c_row0_col20, #T_c6d7c_row0_col33, #T_c6d7c_row1_col21, #T_c6d7c_row9_col20, #T_c6d7c_row10_col37, #T_c6d7c_row15_col7, #T_c6d7c_row16_col18, #T_c6d7c_row18_col27, #T_c6d7c_row19_col10, #T_c6d7c_row19_col36, #T_c6d7c_row26_col18, #T_c6d7c_row26_col22, #T_c6d7c_row31_col21, #T_c6d7c_row32_col22, #T_c6d7c_row32_col23, #T_c6d7c_row34_col24, #T_c6d7c_row36_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_c6d7c_row0_col19, #T_c6d7c_row2_col10, #T_c6d7c_row5_col36, #T_c6d7c_row10_col15, #T_c6d7c_row10_col25, #T_c6d7c_row14_col3, #T_c6d7c_row15_col12, #T_c6d7c_row16_col10, #T_c6d7c_row18_col3, #T_c6d7c_row20_col2, #T_c6d7c_row21_col35, #T_c6d7c_row22_col16, #T_c6d7c_row24_col1, #T_c6d7c_row24_col35, #T_c6d7c_row30_col21, #T_c6d7c_row31_col1, #T_c6d7c_row32_col8, #T_c6d7c_row32_col16, #T_c6d7c_row33_col7, #T_c6d7c_row36_col2, #T_c6d7c_row37_col35 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c6d7c_row0_col22, #T_c6d7c_row3_col15, #T_c6d7c_row7_col36, #T_c6d7c_row10_col32, #T_c6d7c_row11_col35, #T_c6d7c_row13_col32, #T_c6d7c_row14_col35, #T_c6d7c_row21_col10, #T_c6d7c_row23_col35, #T_c6d7c_row27_col10, #T_c6d7c_row31_col18, #T_c6d7c_row31_col37, #T_c6d7c_row32_col18, #T_c6d7c_row35_col18 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c6d7c_row0_col25, #T_c6d7c_row0_col27, #T_c6d7c_row0_col35, #T_c6d7c_row6_col23, #T_c6d7c_row7_col35, #T_c6d7c_row9_col1, #T_c6d7c_row15_col6, #T_c6d7c_row17_col29, #T_c6d7c_row18_col28, #T_c6d7c_row20_col10, #T_c6d7c_row24_col33, #T_c6d7c_row25_col23, #T_c6d7c_row28_col35, #T_c6d7c_row28_col36, #T_c6d7c_row29_col32, #T_c6d7c_row31_col10, #T_c6d7c_row31_col14, #T_c6d7c_row32_col35, #T_c6d7c_row33_col18, #T_c6d7c_row36_col14, #T_c6d7c_row36_col19 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c6d7c_row0_col28, #T_c6d7c_row0_col29, #T_c6d7c_row5_col13, #T_c6d7c_row15_col20, #T_c6d7c_row21_col0, #T_c6d7c_row30_col16, #T_c6d7c_row31_col28, #T_c6d7c_row33_co

# %%
sorted = corr_matrix["SalePrice"].sort_values(ascending=False)
sorted
# Out:
# SalePrice        1.000000
# OverallQual      0.790982
# GrLivArea        0.708624
# GarageCars       0.640409
# GarageArea       0.623431
# TotalBsmtSF      0.613581
# 1stFlrSF         0.605852
# FullBath         0.560664
# TotRmsAbvGrd     0.533723
# YearBuilt        0.522897
# YearRemodAdd     0.507101
# MasVnrArea       0.472614
# Fireplaces       0.466929
# BsmtFinSF1       0.386420
# WoodDeckSF       0.324413
# 2ndFlrSF         0.319334
# OpenPorchSF      0.315856
# HalfBath         0.284108
# LotArea          0.263843
# GarageYrBlt      0.261366
# BsmtFullBath     0.227122
# BsmtUnfSF        0.214479
# LotFrontage      0.209624
# BedroomAbvGr     0.168213
# ScreenPorch      0.111447
# PoolArea         0.092404
# MoSold           0.046432
# 3SsnPorch        0.044584
# BsmtFinSF2      -0.011378
# BsmtHalfBath    -0.016844
# MiscVal         -0.021190
# Id              -0.021917
# LowQualFinSF    -0.025606
# YrSold          -0.028923
# OverallCond     -0.077856
# MSSubClass      -0.084284
# EnclosedPorch   -0.128578
# KitchenAbvGr    -0.135907
# Name: SalePrice, dtype: float64

# %%
# p-values for correlation - to check statistical significance
from scipy.stats import pearsonr

pearson = []
for i in df1.columns:
    if df1.dtypes[i] == np.int64 or df1.dtypes[i] == np.float64:
        #print(i)
        pearson.append((i, pearsonr(df1[i], df1['SalePrice'])))

#sort pearson list based on correlation coefficient
pearson.sort(key=lambda x: x[1][0], reverse=True)
pearson
# Out:
# [('SalePrice', PearsonRResult(statistic=0.9999999999999999, pvalue=0.0)),
#  ('OverallQual',
#   PearsonRResult(statistic=0.7909816005838048, pvalue=2.185675268e-313)),
#  ('GrLivArea',
#   PearsonRResult(statistic=0.708624477612652, pvalue=4.51803364677827e-223)),
#  ('GarageCars',
#   PearsonRResult(statistic=0.6404091972583521, pvalue=2.4986441671775153e-169)),
#  ('GarageArea',
#   PearsonRResult(statistic=0.6234314389183616, pvalue=5.2650381679755234e-158)),
#  ('TotalBsmtSF',
#   PearsonRResult(statistic=0.6135805515591954, pvalue=9.484229391500708e-152)),
#  ('1stFlrSF',
#   PearsonRResult(statistic=0.6058521846919146, pvalue=5.394710618967361e-147)),
#  ('FullBath',
#   PearsonRResult(statistic=0.560663762748446, pvalue=1.2364700667597597e-121)),
#  ('TotRmsAbvGrd',
#   PearsonRResult(statistic=0.5337231555820282, pvalue=2.772280932956307e-108)),
#  ('YearBuilt',
#   PearsonRResult(statistic=0.5228973328794968, pvalue=2.9902290990137165e-103)),
#  ('YearRemodAdd',
#   PearsonRResult(statistic=0.5071009671113862, pvalue=3.1649482419179543e-96)),
#  ('MasVnrArea',
#   PearsonRResult(statistic=0.47261449900457375, pvalue=4.1004610445367704e-82)),
#  ('Fireplaces',
#   PearsonRResult(statistic=0.46692883675152774, pvalue=6.1414874611153174e-80)),
#  ('BsmtFinSF1',
#   PearsonRResult(statistic=0.38641980624215333, pvalue=3.394109829288658e-53)),
#  ('WoodDeckSF',
#   PearsonRResult(statistic=0.3244134445681299, pvalue=3.972216535626657e-37)),
#  ('2ndFlrSF',
#   PearsonRResult(statistic=0.3193338028320678, pvalue=5.764335119178691e-36)),
#  ('OpenPorchSF',
#   PearsonRResult(statistic=0.3158562271160553, pvalue=3.493373623094744e-35)),
#  ('HalfBath',
#   PearsonRResult(statistic=0.28410767559478256, pvalue=1.6504733955718873e-28)),
#  ('LotArea',
#   PearsonRResult(statistic=0.2638433538714057, pvalue=1.1231391549186638e-24)),
#  ('GarageYrBlt',
#   PearsonRResult(statistic=0.2613664351029631, pvalue=3.139250309923686e-24)),
#  ('BsmtFullBath',
#   PearsonRResult(statistic=0.22712223313149424, pvalue=1.550344137213464e-18)),
#  ('BsmtUnfSF',
#   PearsonRResult(statistic=0.21447910554696892, pvalue=1.182975796359376e-16)),
#  ('LotFrontage',
#   PearsonRResult(statistic=0.2096239447994839, pvalue=5.824303154720268e-16)),
#  ('BedroomAbvGr',
#   PearsonRResult(statistic=0.16821315430073996, pvalue=9.927497326179095e-11)),
#  ('ScreenPorch',
#   PearsonRResult(statistic=0.1114465711429112, pvalue=1.9721400194689477e-05)),
#  ('PoolArea',
#   PearsonRResult(statistic=0.0924035494918732, pvalue=0.00040734896011961725)),
#  ('MoSold',
#   PearsonRResult(statistic=0.04643224522381934, pvalue=0.07612757850604744)),
#  ('3SsnPorch',
#   PearsonRResult(statistic=0.04458366533574841, pvalue=0.08858170358056278)),
#  ('BsmtFinSF2',
#   PearsonRResult(statistic=-0.011378121450215141, pvalue=0.6639986508340907)),
#  ('BsmtHalfBath',
#   PearsonRResult(statistic=-0.016844154297359012, pvalue=0.5201536357277567)),
#  ('MiscVal',
#   PearsonRResult(statistic=-0.02118957964030326, pvalue=0.41848634940803825)),
#  ('Id',
#   PearsonRResult(statistic=-0.021916719443431112, pvalue=0.40269379975577235)),
#  ('LowQualFinSF',
#   PearsonRResult(statistic=-0.02560613000067956, pvalue=0.32820730984052837)),
#  ('YrSold',
#   PearsonRResult(statistic=-0.028922585168730326, pvalue=0.2694131932808431)),
#  ('OverallCond',
#   PearsonRResult(statistic=-0.07785589404867801, pvalue=0.002912351267915519)),
#  ('MSSubClass',
#   PearsonRResult(statistic=-0.0842841351265952, pvalue=0.0012664716847494539)),
#  ('EnclosedPorch',
#   PearsonRResult(statistic=-0.12857795792595675, pvalue=8.255770475113277e-07)),
#  ('KitchenAbvGr',
#   PearsonRResult(statistic=-0.1359073708421412, pvalue=1.8604260320752864e-07))]

# %%
# subplots for top 10 correlated numeric variables

fig, axes = plt.subplots(5,2, figsize=(10, 15))
axes = axes.flatten()
for i in range(len(sorted[1:11])): # exclude SalePrice
    sns.regplot(x=sorted.index[i+1], y='SalePrice', data=df1, ax=axes[i])
    axes[i].set_xlabel(sorted.index[i+1])
    axes[i].set_ylabel('SalePrice')
plt.tight_layout()
plt.show()

# %%
# Violin plots for categorical variables
fig, axes = plt.subplots(15,3, figsize=(10, 15))
axes = axes.flatten()
for i in range(len(df1.columns)):
    if df1[df1.columns[i]].dtype == 'object' and df1.columns[i]!= 'SalePrice':
        sns.violinplot(x=df1.columns[i+1], y='SalePrice', data=df1, ax=axes[i])
        axes[i].set_xlabel(df1.columns[i+1])
        axes[i].set_ylabel('SalePrice')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# d:\Projects_Github\ml-processing-pipeline-for-predicting-houseprices\DatasetExplore.ipynb Cell 20 line 6
#       <a href='vscode-notebook-cell:/d%3A/Projects_Github/ml-processing-pipeline-for-predicting-houseprices/DatasetExplore.ipynb#X23sZmlsZQ%3D%3D?line=3'>4</a> for i in range(len(df1.columns)):
#       <a href='vscode-notebook-cell:/d%3A/Projects_Github/ml-processing-pipeline-for-predicting-houseprices/DatasetExplore.ipynb#X23sZmlsZQ%3D%3D?line=4'>5</a>     if df1[df1.columns[i]].dtype == 'object' and df1.columns[i]!= 'SalePrice':
# ----> <a href='vscode-notebook-cell:/d%3A/Projects_Github/ml-processing-pipeline-for-predicting-houseprices/DatasetExplore.ipynb#X23sZmlsZQ%3D%3D?line=5'>6</a>         sns.violinplot(x=df1.columns[i+1], y='SalePrice', data=df1, ax=axes[i])
#       <a href='vscode-notebook-cell:/d%3A/Projects_Github/ml-processing-pipeline-for-predicting-houseprices/DatasetExplore.ipynb#X23sZmlsZQ%3D%3D?line=6'>7</a>         axes[i].set_xlabel(df1.columns[i+1])
#       <a href='vscode-notebook-cell:/d%3A/Projects_Github/ml-processing-pipeline-for-predicting-houseprices/DatasetExplore.ipynb#X23sZmlsZQ%3D%3D?line=7'>8</a>         axes[i].set_ylabel('SalePrice')
#
# IndexError: index 53 is out of bounds for axis 0 with size 45

# %%
df1['SalePrice'].dtype
# Out:
# dtype('int64')
